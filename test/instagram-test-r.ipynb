# %%
chooseCRANmirror(ind=81)

# %%
devtools::install_github("pablobarbera/instaR/instaR")
# Out:
# Skipping install for github remote, the SHA1 (56ba5c92) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
library(instaR)
# Out:
# Loading required package: httr
# Warning message:
# : package ‘httr’ was built under R version 3.2.3Loading required package: rjson

# %%
??instaR

# %%
?instaR::instaOAuth
# Out:
# instaOAuth               package:instaR                R Documentation
#
# n
#
# n:
#
#      ‘instaOAuth’ creates an OAuth access token that enables R to make
#      authenticated calls to the Instagram API. The token can be saved
#      as a file in disk to be re-used in future sessions. This function
#      relies on the ‘httr’ package to create the OAuth token, and is a
#      simplified version of one of its examples.
#
# e:
#
#      instaOAuth(app_id, app_secret, scope = "basic")
#
# s:
#
#   app_id: numeric, Client ID of application to be used to create OAUth
#           token. Available at <URL: http://instagram.com/developer>
#
# app_secret: string, Client Secret of application to be used to create
#           OAUth token. Available at <URL:
#           http://instagram.com/developer>.
#
#    scope: string, specifies scope of access to the authenticated user
#           data. See <URL:
#           http://instagram.com/developer/authentication/#scope> for
# ...

# %%
ls(gtrend)
# Out:
# Warning message:
# In ls(gtrend): ‘gtrend’ converted to character string
# Error in as.environment(pos): no item called "gtrend" on the search list

# %%
g_username = "analytics.mirum.toronto@gmail.com"
g_password = "Mirum.123"
path = "/users/vivek.menon/Data"

# %%
?"%>%"
# Out:
# Warning message:
# In find.package(if (is.null(package)) loadedNamespaces() else package, : there is no package called ‘gtrendsR’
# %>%                  package:stringr                   R Documentation
#
# r
#
# n:
#
#      Pipe operator
#
# e:
#
#      lhs %>% rhs

# %%
terms <- c(
    "reading assessment", "common core", "reading standards",
    "phonics", "whole language", "lexile score", "balanced approach",
    "literacy research association", "international reading association"
)
 
out <- gtrend_scraper(g_username, g_password, terms)
 
out %>%
    trend2long() %>%
    plot()
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %%
print(out)
# Out:
# $`"reading assessment"`
# $query
#                    query                      cat                      geo
# "\"reading assessment\""                      "0"                     "US"
#                     time
#    "2016-04-13 13:55:07"
#
# $meta
#  [1] "HTTP/1.1 302 Moved Temporarily"
#  [2] "Content-Type: text/html; charset=UTF-8"
#  [3] "Cache-Control: no-cache, no-store, max-age=0, must-revalidate"
#  [4] "Pragma: no-cache"
#  [5] "Expires: Fri, 01 Jan 1990 00:00:00 GMT"
#  [6] "Date: Wed, 13 Apr 2016 17:55:06 GMT"
#  [7] "Location: https://www.google.com/trends/trendsReport?q=%22reading+assessment%22&geo=US&content=1&export=1"
#  [8] "X-Content-Type-Options: nosniff"
#  [9] "X-Frame-Options: SAMEORIGIN"
# [10] "X-XSS-Protection: 1; mode=block"
# [11] "Server: GSE"
# [12] "Alternate-Protocol: 443:quic"
# [13] "Alt-Svc: quic=\":443\"; ma=2592000; v=\"32,31,30,29,28,27,26,25\""
# [14] "Accept-Ranges: none"
# [15] "Vary: Accept-Encoding"
# [16] "Transfer-Encoding: chunked"
# ...

# %%
print(out$"international reading association"$query)
# Out:
# NULL
