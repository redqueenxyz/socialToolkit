# %%
import requests

# %%
url = "https://api.crimsonhexagon.com/api/authenticate"

querystring = {
  "username":"vivek.menon@jptbwa.com",
  "noExpiration":"true",
  "password":"vivekmenon1"
}

response = requests.request("GET", url, params=querystring)

print(response.text)
# Out:
# {"auth":"mOZ6y5nvHMsqf1QChCUVZ9rrDaFnALKQ3j5bctxubo4","status":"success"}

# %% [markdown]
# February 26th and 28th 2016
#
# February 27th 2015
#
# February 28th 2014

# %%
class Crimson(:
    """
    Class for querying Crimson API.
    """
    import requests
    
    
    def __init__(self, name, auth):
        self.name = name
        self.auth = None
        
        self.authurl = "https://api.crimsonhexagon.com/api/authenticate"
        self.monitorurl = "https://api.crimsonhexagon.com/api/monitor/dayandtime"
        
    def auth(username, password, noExpiration=True):
        response = requests.request("GET", url, params=querystring)
        print(response.text)

# %%
monitor = "https://api.crimsonhexagon.com/api/monitor/dayandtime"

monitorparams = {
    "id" : "5061172411",
    "auth":"mOZ6y5nvHMsqf1QChCUVZ9rrDaFnALKQ3j5bctxubo4",
    "start":"2014-01-01",
    "end":"2017-01-01",
    "aggregatebyday":"true",
    "uselocaltime":"true"
}

monitorresult = requests.request("GET", monitor, params=monitorparams)

print(monitorresult.text)
# Out:
# {"volumes":[{"startDate":"2015-11-01T00:00:00","endDate":"2015-11-02T00:00:00","numberOfDocuments":25,"volume":{"Monday":0,"Thursday":0,"Friday":0,"Sunday":5,"Wednesday":0,"Tuesday":0,"Saturday":0}},{"startDate":"2015-11-02T00:00:00","endDate":"2015-11-03T00:00:00","numberOfDocuments":33,"volume":{"Monday":5,"Thursday":0,"Friday":0,"Sunday":2,"Wednesday":0,"Tuesday":0,"Saturday":0}},{"startDate":"2015-11-03T00:00:00","endDate":"2015-11-04T00:00:00","numberOfDocuments":43,"volume":{"Monday":0,"Thursday":0,"Friday":0,"Sunday":0,"Wednesday":0,"Tuesday":7,"Saturday":0}},{"startDate":"2015-11-04T00:00:00","endDate":"2015-11-05T00:00:00","numberOfDocuments":33,"volume":{"Thursday":2,"Monday":0,"Friday":0,"Sunday":0,"Wednesday":9,"Tuesday":0,"Saturday":0}},{"startDate":"2015-11-05T00:00:00","endDate":"2015-11-06T00:00:00","numberOfDocuments":28,"volume":{"Thursday":4,"Monday":0,"Friday":0,"Sunday":0,"Wednesday":0,"Tuesday":0,"Saturday":0}},{"startDate":"2015-11-06T00:00:00","endDate":"2015-
# ...
